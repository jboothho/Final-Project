# %% [markdown]
# # Receiving C++ Data and Transforming to ArcGIS Online #

# %% [markdown]
#  First, import ArcGIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
from arcgis.widgets import MapView
from arcgis.features import FeatureLayer
from arcgis.gis import GIS
from arcgis import features
from arcgis.features import FeatureCollection
from arcgis.features import GeoAccessor, GeoSeriesAccessor
from arcgis.geocoding import geocode
from arcgis.features.analysis import join_features

# %%
gis = GIS(
  url="https://www.arcgis.com",
  username="jboothhowe",
  password="Jujubeads777!")

# %%
m = gis.map("Boston, MA")

# Read CSV file generated by C++ program
csv_file_path = "/Users/jboothhowe/Documents/CS2300/Final-Project/cmake-build-debug/DataToMap.csv"
data = pd.read_csv(csv_file_path)

# Extract columns (geoID, var1, var2) from CSV
geoID = list(data['GeoID'])
var1 = list(data['UrbanHeat_Variable'])
var2 = list(data['SVI_Variable'])

stuff = gis.content.search(query = 'owner :"jboothho@uvm.edu_UVM"', item_type = 'Feature Layer')
stuff
#boston_census_tracts = stuff[4]
#m.add_layer(census_tracts)
#m
# Out:
# []

# %%
# Define the attribute relationship (join fields)
attribute_relationship = [{"CODE": "geoID"}]

join_result = join_features(
    target_layer=census_group,
    join_layer=data,
    attribute_relationship=attribute_relationship,  # No spatial relationship (attribute join)
    join_type="KEEP_ALL",  # Keep all features from the target layer
    output_name="Joined_Layer"  # Name for the output joined layer (optional)
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 8
#       5 # Define the attribute relationship (join fields)
#       6 attribute_relationship = [{"CODE": "geoID"}]
# ----> 8 join_result = join_features(
#       9     target_layer=census_group,
#      10     join_layer=data,
#      11     attribute_relationship=attribute_relationship,  # No spatial relationship (attribute join)
#      12     join_type="KEEP_ALL",  # Keep all features from the target layer
#      13     output_name="Joined_Layer"  # Name for the output joined layer (optional)
#      14 )
#
# ...
